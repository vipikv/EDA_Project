# %% [markdown]
# <h1 style="color: darkblue">
#     Exploratory Data Analysis on Employees dataset
# </h1>

# %% [markdown]
# <p style="color: darkblue;font-size:larger">Import necessary modules</p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <p style="color: darkblue;font-size:larger">read dataset</p>

# %%
data = pd.read_csv('abc-company.csv')
df = data
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
# 457  False  False   False     False  False   False   False    False   False
#
# [458 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df.notnull()
# Out:
#      Name  Team  Number  Position   Age  Height  Weight  College  Salary
# 0    True  True    True      True  True    True    True     True    True
# 1    True  True    True      True  True    True    True     True    True
# 2    True  True    True      True  True    True    True     True   False
# 3    True  True    True      True  True    True    True     True    True
# 4    True  True    True      True  True    True    True    False    True
# ..    ...   ...     ...       ...   ...     ...     ...      ...     ...
# 453  True  True    True      True  True    True    True     True    True
# 454  True  True    True      True  True    True    True    False    True
# 455  True  True    True      True  True    True    True    False    True
# 456  True  True    True      True  True    True    True     True    True
# 457  True  True    True      True  True    True    True     True    True
#
# [458 rows x 9 columns]

# %%
df.notnull().sum()
# Out:
# Name        458
# Team        458
# Number      458
# Position    458
# Age         458
# Height      458
# Weight      458
# College     374
# Salary      447
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Length: 458, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Team'].unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
df['Team'].nunique()
# Out:
# 30

# %%
df[['Name','Team','Salary']]
# Out:
#               Name            Team     Salary
# 0    Avery Bradley  Boston Celtics  7730337.0
# 1      Jae Crowder  Boston Celtics  6796117.0
# 2     John Holland  Boston Celtics        NaN
# 3      R.J. Hunter  Boston Celtics  1148640.0
# 4    Jonas Jerebko  Boston Celtics  5000000.0
# ..             ...             ...        ...
# 453   Shelvin Mack       Utah Jazz  2433333.0
# 454      Raul Neto       Utah Jazz   900000.0
# 455   Tibor Pleiss       Utah Jazz  2900000.0
# 456    Jeff Withey       Utah Jazz   947276.0
# 457       Priyanka       Utah Jazz   947276.0
#
# [458 rows x 3 columns]

# %% [markdown]
# <p style="color: darkblue;font-size:x-large"> column height is having incorrect data, changing the data of that particular column with any random numbers between 150 and 180.</p>

# %%
df['Height']
# Out:
# 0      06-Feb
# 1      06-Jun
# 2      06-May
# 3      06-May
# 4      06-Oct
#         ...
# 453    06-Mar
# 454    06-Jan
# 455    07-Mar
# 456       7-0
# 457    07-Mar
# Name: Height, Length: 458, dtype: object

# %%
x = np.random.randint(150,180,len(df['Height']))
df['Height'] = x

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     168     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     171     235
# 2     John Holland  Boston Celtics      30       SG   27     159     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     172     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     160     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     156     203
# 454      Raul Neto       Utah Jazz      25       PG   24     159     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     178     256
# 456    Jeff Withey       Utah Jazz      24        C   26     169     231
# 457       Priyanka       Utah Jazz      34        C   25     158     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# <p style="color: darkblue;font-size:x-large"> How many are there in each Team and the percentage splitting with respect to the total employees.</p>

# %% [markdown]
# <p style="color: darkblue;font-size:medium">Employees in each group</p>

# %%
df['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %% [markdown]
# <p style="color: darkblue;font-size:large">Percetage of employees in each group with respect to total employees</p>

# %% [markdown]
# <p style="color: darkblue;font-size:medium">Percenatge of employees in each group</p>

# %%
percentage_split = (df['Team'].value_counts()/len(df))*100
percentage = percentage_split.round(2)
percentageDF = pd.DataFrame({'Team':df['Team'].value_counts(),'percentage split':percentage})
percentageDF
# Out:
#                         Team  percentage split
# Team
# New Orleans Pelicans      19              4.15
# Memphis Grizzlies         18              3.93
# Utah Jazz                 16              3.49
# New York Knicks           16              3.49
# Milwaukee Bucks           16              3.49
# Brooklyn Nets             15              3.28
# Portland Trail Blazers    15              3.28
# Oklahoma City Thunder     15              3.28
# Denver Nuggets            15              3.28
# Washington Wizards        15              3.28
# Miami Heat                15              3.28
# Charlotte Hornets         15              3.28
# Atlanta Hawks             15              3.28
# San Antonio Spurs         15              3.28
# Houston Rockets           15              3.28
# Boston Celtics            15              3.28
# Indiana Pacers            15              3.28
# Detroit Pistons           15              3.28
# Cleveland Cavaliers       15              3.28
# ...

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x=percentageDF['Team'].index, y='percentage split', data=percentageDF, palette='tab10',hue=percentageDF['Team'].index)
plt.title('Percentage split')
plt.xlabel('Team')
plt.ylabel('Percentage')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <p style="color: darkgreen;font-size:medium">Data Story</p>

# %% [markdown]
# <p style="color: darkgreen;font-size:medium">From the bar plot based on teams and their respective percentage of employees, team New Orleans Pelicans has the most number of employees.It has Total of 19 employees which is 4.15 percentage of total employees in the company</p>

# %% [markdown]
# <p style="color: darkblue;font-size:x-large"> Segregate the employees w.r.t different positions</p>

# %%
position_counts = df['Position'].value_counts()
position_counts
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
df[['Position','Name']]
# Out:
#     Position           Name
# 0         PG  Avery Bradley
# 1         SF    Jae Crowder
# 2         SG   John Holland
# 3         SG    R.J. Hunter
# 4         PF  Jonas Jerebko
# ..       ...            ...
# 453       PG   Shelvin Mack
# 454       PG      Raul Neto
# 455        C   Tibor Pleiss
# 456        C    Jeff Withey
# 457        C       Priyanka
#
# [458 rows x 2 columns]

# %%
groupby_position = df.groupby('Position')['Name']

# %%
for position, name in groupby_position:
    print(f"Position: {position}")
    print(f"name: {name}")
# Out:
# Position: C
# name: 7         Kelly Olynyk
# 10     Jared Sullinger
# 14        Tyler Zeller
# 23         Brook Lopez
# 27          Henry Sims
#             ...
# 439      Mason Plumlee
# 447        Rudy Gobert
# 455       Tibor Pleiss
# 456        Jeff Withey
# 457           Priyanka
# Name: Name, Length: 79, dtype: object
# Position: PF
# name: 4         Jonas Jerebko
# 5          Amir Johnson
# 6         Jordan Mickey
# 24     Chris McCullough
# 25          Willie Reed
#              ...
# 435      Meyers Leonard
# 441         Noah Vonleh
# 442       Trevor Booker
# 446      Derrick Favors
# 452          Trey Lyles
# Name: Name, Length: 100, dtype: object
# Position: PG
# name: 0      Avery Bradley
# 8       Terry Rozier
# 9       Marcus Smart
# 11     Isaiah Thomas
# 19      Jarrett Jack
#            ...
# 440    Brian Roberts
# 443       Trey Burke
# 445       Dante Exum
# 453     Shelvin Mack
# 454        Raul Neto
# Name: Name, Length: 92, dtype: object
# Position: SF
# ...

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='Position',data=df,palette='rocket',hue='Position')
plt.title("employee position")
# Out:
# Text(0.5, 1.0, 'employee position')

# %% [markdown]
# <p style="color: darkgreen;font-size:medium">Data Story</p>

# %% [markdown]
# <p style="color: darkgreen;font-size:medium">From the barplot it is observed that position SG has the most number of employeesfollowed by PF which has the second largest employee counts.position SG has 102 employees and position PF has 100 employees. position C has the least number of employees of 79. </p>

# %% [markdown]
# <p style="color: darkblue;font-size:x-large"> Find from which age group most of the employees belong to.
# </p>

# %%
age1 = df['Age'].value_counts()
age1
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='Age',data=df,palette='rocket',hue='Age')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# <p style="color: darkgreen;font-size:medium">Data Story</p>

# %% [markdown]
# <p style="color: darkgreen;font-size:medium">Based on age of employees it is observed that most of the employees belong to the age group of 24 with 47 employees.It is then followed by age of 25 and 27,which has employee count of 46 and 41 respectively.Age group of 39 and 19 has least number of employees,both age groups have employee count of 2.</p>

# %% [markdown]
# <p style="color: darkblue;font-size:x-large">Find out under which team and position, spending in terms of salary is high
# </p>

# %%
df[['Team','Position','Salary']]
# Out:
#                Team Position     Salary
# 0    Boston Celtics       PG  7730337.0
# 1    Boston Celtics       SF  6796117.0
# 2    Boston Celtics       SG        NaN
# 3    Boston Celtics       SG  1148640.0
# 4    Boston Celtics       PF  5000000.0
# ..              ...      ...        ...
# 453       Utah Jazz       PG  2433333.0
# 454       Utah Jazz       PG   900000.0
# 455       Utah Jazz        C  2900000.0
# 456       Utah Jazz        C   947276.0
# 457       Utah Jazz        C   947276.0
#
# [458 rows x 3 columns]

# %%
total_salary_spend = df.groupby(['Team','Position'])['Salary'].sum()
max_salary = total_salary_spend.max()
max_salary_index = total_salary_spend.idxmax()
max_salary_index
max_salary
print(f"maximum salary spend {max_salary}, spend by {max_salary_index}")
# Out:
# maximum salary spend 31866445.0, spend by ('Los Angeles Lakers', 'SF')

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df,x=df['Team'],y=df['Salary'],hue=df['Position'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p style="color: darkgreen;font-size:medium">Data Story</p>

# %% [markdown]
# <p style="color: darkgreen;font-size:medium">Based on observing scatter graph Los Angeles Lakers team's position of SF where the highest spending of salary occures.The total combined salary of this Los Angeles Lakers with position SF is 31866445</p>

# %% [markdown]
# <p style="color: darkblue;font-size:x-large">Find if there is any correlation between age and salary , represent it visually
# </p>

# %%
df['Age'].corr(df['Salary'])
# Out:
# 0.2140094122657097

# %%
corr_matrix = df[['Age','Salary']].corr()
corr_matrix
# Out:
#              Age    Salary
# Age     1.000000  0.214009
# Salary  0.214009  1.000000

# %%
sns.heatmap(corr_matrix,annot=True,cmap='rocket')
plt.title('correlation of Age and Salary')
plt.show()

# %% [markdown]
# <p style="color: darkgreen;font-size:medium">Data Story</p>

# %% [markdown]
# <ul>
#     <p style="color: darkgreen;font-size:large">From the heatmap it shows the correlation of Age and Salary</p>
#     <li>
#         <p style="color: darkgreen;font-size:medium">the correlation coefficient of age to age is 1,which is a perfect correlation</p>
#     </li>
#     <li>
#         <p style="color: darkgreen;font-size:medium">the correlation coefficient of age to salary is 0.21.Age is positively correlated to salary, the correlation of 0.21 indicates that the positive correlation is in minimal strength.When age increases salary tend to increase slightly</p>
#     </li>
#     <li>
#         <p style="color: darkgreen;font-size:medium">the correlation cosfficient of salary to age is 0.21 ,salary is a positively correlated to Age.The positive correlation of 0.21 shows that the correlation is in in minimal strength.
#         when salary increase for employees their respective age seem to increase slightly</p>
#     </li>
#     <li>
#         <p style="color: darkgreen;font-size:medium">the correlation between salary to salary is 1 ,which is a perfect correlation.</p>
#     </li>
# </ul>
